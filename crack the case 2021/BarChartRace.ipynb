# %%
import pandas as pd
import numpy as np

# %%
df = pd.ExcelFile('barkuy.xlsx', engine='openpyxl')
prosperity = pd.read_excel(df, 'Prosperity', index_col=0)
prosperity.columns = prosperity.columns.map(str)
cols = ['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       '2016']

# %%
prosperity.columns
# Out:
# Index(['2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016'],
#       dtype='object')

# %%
country = [
    "Kenya",
    "Malawi",
    "Macedonia"
]

prosperity
data = prosperity[cols]
a = data.T[country]

a
# Out:
# country  Kenya  Malawi  Macedonia
# 2007        96      93         71
# 2008       112      94         64
# 2009       114      87         62
# 2010       107      90         65
# 2011       105     106         64
# 2012       109     101         70
# 2013        99     104         49
# 2014       100     109         47
# 2015        97     110         52
# 2016        97     110         53

# %%
import bar_chart_race as bcr

bcr.bar_chart_race(a, sort='asc', steps_per_period = 80, period_length=2000, title='Prosperity Index Ranking',dpi=288)
# Out:
# C:\Users\arkan\miniconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\arkan\miniconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="1856" height="1008" controls autoplay loop>
#   <source type="video/mp4" src="...
